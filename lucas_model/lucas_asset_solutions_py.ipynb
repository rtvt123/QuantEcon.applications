# %% [markdown]
# # quant-econ Solutions: The Lucas Asset Pricing Model

# %% [markdown]
# Solutions for http://quant-econ.net/py/lucas_model.html

# %%
# %matplotlib inline

# %% [markdown]
# Let's start with standard imports

# %%
import numpy as np
import matplotlib.pyplot as plt
from lucastree import LucasTree, compute_lt_price

# %% [markdown]
# ## Exercise 1

# %%
fig, ax = plt.subplots(figsize=(10,7))

ax.set_xlabel(r'$y$', fontsize=16)
ax.set_ylabel(r'price', fontsize=16)

for beta in (.95, 0.98):
    print("Computing at beta = {}".format(beta))
    tree = LucasTree(gamma=2, beta=beta, alpha=0.90, sigma=0.1)
    grid = tree.grid
    price_vals = compute_lt_price(tree)
    label = r'$\beta = {}$'.format(beta)
    ax.plot(grid, price_vals, lw=2, alpha=0.7, label=label)

ax.legend(loc='upper left')
ax.set_xlim(min(grid), max(grid))
# Out:
# Computing at beta = 0.95
# Computing at beta = 0.98
# (0.39945149497311855, 2.5034328637756031)
